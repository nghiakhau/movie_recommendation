# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
#import os
import shutil
import sys

import numpy as np
from scipy import sparse

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sn
sn.set()
from collections import Counter
import pandas as pd
import torch.nn as nn
import torch.nn.functional as F
import torch
import torch.optim as optim

from torch.autograd import Variable
import pickle
import warnings
warnings.filterwarnings('ignore')
import time
import spacy
import math, copy
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import scipy
from scipy.sparse import csr_matrix, hstack, save_npz, load_npz

# %%
PATH = 'data/user_based'
PATH
# Out:
# 'data/user_based'

# %%
va_tr_data = load_npz(os.path.join(PATH,'ub_va_tr_data.npz'))
va_te_data = load_npz(os.path.join(PATH,'ub_va_te_data.npz'))

va_tr_data.shape, va_te_data.shape
# Out:
# ((10000, 20497), (10000, 20497))

# %%
data = load_npz(os.path.join(PATH,'ub_tr_data.npz'))

data.shape
# Out:
# (115806, 20497)

# %%
te_tr_data = load_npz(os.path.join(PATH,'ub_te_tr_data.npz'))
te_te_data = load_npz(os.path.join(PATH,'ub_te_te_data.npz'))

te_tr_data.shape, te_te_data.shape
# Out:
# ((10000, 20497), (10000, 20497))

# %%
unique_mid = []
with open(os.path.join(PATH, 'ub_unique_mid.txt'), 'r') as f:
    for line in f:
        unique_mid.append(line.strip())

n_items = len(unique_mid)
n_items
# Out:
# 20497

# %%
mid2id = dict((mid, i) for (i, mid) in enumerate(unique_mid))
id2mid = dict((i, mid) for (i, mid) in enumerate(unique_mid))

# %%
movie_descriptions = pd.read_csv('data/item_embeddings/sum_embs.csv')
movie_descriptions['sum_embs'] = movie_descriptions['sum_embs'].map(lambda x : np.fromstring(x[1:-1], sep=','))
movie_descriptions.head(2)
# Out:
#    movieId  id                                           sum_embs
# 0        1   0  [0.2797650992870331, -0.12578724324703217, -0....
# 1        2   1  [-0.045451000332832336, -0.2998088002204895, -...

# %%
movie_embs = movie_descriptions['sum_embs'].tolist()
movie_embs = np.array(movie_embs)
movie_embs.shape
# Out:
# (20497, 300)

# %%
import numpy as np

# %%
a = np.array([1,2,3])

# %%
np.random.shuffle(a)
a
# Out:
# array([2, 3, 1])

# %%
device = torch.device('cuda')
device
# Out:
# device(type='cuda')

# %%
def recall_at_k(pred, true, k):
    tmp = np.intersect1d(pred[:k], true)
    return len(tmp)/np.minimum(len(true), k)

# %%
class User_Embeddings(nn.Module):
    
    def __init__(self, movies_embeddings, att_dims, fc_dims, drop=0.2):
        super(User_Embeddings, self).__init__()
        
        self.movies_embeddings = movies_embeddings
        
        "Initialization Layers", 
        self.att_layers = nn.ModuleList([nn.Linear(d_in, d_out, bias=False) for
                                        (d_in, d_out) in zip(att_dims[:-1], att_dims[1:])])
        
        self.fc_layers = nn.ModuleList([nn.Linear(d_in, d_out) for
                                        (d_in, d_out) in zip(fc_dims[:-1], fc_dims[1:])])
        self.drop = nn.Dropout(drop)
        self.init_weights()

        
    def attention(self, data): 
        h = F.normalize(data)
        #h = data
        for i, layer in enumerate(self.att_layers):
            h = self.drop(h)
            h = layer(h)
            if not i == len(self.att_layers) - 1:
                h = torch.tanh(h)
            else:
                h = torch.softmax(h, 0)           
        return h
    
    
    def prediction(self, data):
        h = torch.flatten(data)
        #h = self.drop(h)
        for i, layer in enumerate(self.fc_layers):
            h = self.drop(h)
            h = layer(h)
            if not i == len(self.fc_layers) - 1:
                h = torch.relu(h)
            else:
                h = torch.sigmoid(h)

        return h
        
        
    def forward(self, ind):
        h = self.movies_embeddings[ind]
        z = self.attention(h)
        h = torch.mm(h.t(), z)
        h = self.prediction(h)

        return h
    
    
    def init_weights(self):
        for layer in self.att_layers:
            fan_out, fan_in = layer.weight.size()
            std = np.sqrt(2.0/(fan_in + fan_out))
            layer.weight.data.normal_(0.0, std)
            #layer.bias.data.normal_(0.0, 0.001)
            
        for layer in self.fc_layers:
            fan_out, fan_in = layer.weight.size()
            std = np.sqrt(2.0/(fan_in + fan_out))
            layer.weight.data.normal_(0.0, std)
            layer.bias.data.normal_(0.0, 0.001)

# %%
n_users, _ = data.shape

idxlist = list(range(n_users))

# %%
def att_train(data):
    model.train()
    np.random.shuffle(idxlist)
    for batch_ind, start_idx in enumerate(range(0, n_users, batch_size)):
        end_idx = min(start_idx + batch_size, n_users)
        batch_data = data[idxlist[start_idx:end_idx]]
        
        optimizer.zero_grad()
        batch_loss =  None
        for d in batch_data:
            item_like_tr = torch.LongTensor(d.nonzero()[1]).to(device)
            input_ = torch.FloatTensor(d.toarray()).view(-1,1).to(device)
            att_pred = model(item_like_tr)
            if batch_loss :
                batch_loss += criterion(att_pred, input_) 
            else:
                batch_loss = criterion(att_pred, input_)
        batch_loss.backward()
        optimizer.step()


def att_test(val_tr, val_te):
    model.eval()
    r_20 = []
    r_50 = []
    val_loss = 0.0
    
    with torch.no_grad():
        for i in range(val_tr.shape[0]):
            input_ = val_tr[i]
            output = val_te[i]

            item_like_tr = input_.nonzero()[1]
            item_like_te = output.nonzero()[1]

            input_ = torch.FloatTensor(input_.toarray()).to(device) 

            att_pred = model(torch.LongTensor(item_like_tr).to(device)) 
            
            att_pred_np = att_pred.data.cpu().numpy()
            att_pred_np[item_like_tr] = -np.inf

            "Compute loss"
            loss = criterion(att_pred, input_)
            val_loss += loss.item()
            
            "Compute recall"
            pred_item = (-att_pred_np).argsort(axis=0)
                
            r_20.append(recall_at_k(pred_item, item_like_te, 20))
            r_50.append(recall_at_k(pred_item, item_like_te, 50))

    val_loss /= val_tr.shape[0]
    return np.mean(r_20), np.mean(r_50), val_loss

# %%
batch_size = 256
best_recall = -np.inf
n_epochs = 300

# %%
emb_size = movie_embs.shape[1]
emb_size
# Out:
# 300

# %%
tensor_movie_embs = torch.FloatTensor(movie_embs).to(device)
att_dims = [emb_size, 100, 50]
fc_dims = [att_dims[0]*att_dims[-1], 600, n_items]
att_dims, fc_dims
# Out:
# ([300, 100, 50], [15000, 600, 20497])

# %%
"Create Attention model, define optimization and loss"

model = User_Embeddings(tensor_movie_embs, att_dims, fc_dims).to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-4)
criterion = torch.nn.BCELoss()

# %%
log_dir = 'models/user_embeddings/'
log_dir
# Out:
# 'models/user_embeddings/'

# %%
"Batch 1"
try:
    r_20 = []
    r_50 = []
    print('Train with {} users and validate with {} users'.format(data.shape[0], va_tr_data.shape[0]))
    for epoch in range(1, n_epochs + 1):
        epoch_start_time = time.time()
        att_train(data)
        r2, r5, loss = att_test(va_tr_data, va_te_data)
        r_20.append(r2)
        r_50.append(r5)
        print('-' * 94)
        print('| end of epoch {:3d} | time: {:4.2f}s | val loss: {:4.4f} | recall@20 {:4.4f} | recall@50 {:4.4f} |'.format(epoch, time.time() - epoch_start_time, loss, r2, r5))
        print('-' * 94)

        if r2 > best_recall:
            with open(log_dir + 'user_embs_sum.pt', 'wb') as f:
                torch.save(model, f)
            best_recall = r2

    print(np.mean(r_20))
    print(np.mean(r_50))

except KeyboardInterrupt:
    print('-' * 94)
    print('Exiting from training early')
# Out:
# Train with 115806 users and validate with 10000 users
# ----------------------------------------------------------------------------------------------
# | end of epoch   1 | time: 1160.34s | val loss: 0.0130 | recall@20 0.1823 | recall@50 0.2673 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch   2 | time: 865.71s | val loss: 0.0125 | recall@20 0.2085 | recall@50 0.3033 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch   3 | time: 879.35s | val loss: 0.0121 | recall@20 0.2140 | recall@50 0.3118 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch   4 | time: 870.08s | val loss: 0.0119 | recall@20 0.2202 | recall@50 0.3179 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch   5 | time: 957.94s | val loss: 0.0116 | recall@20 0.2228 | recall@50 0.3218 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch   6 | time: 1145.99s | val loss: 0.0111 | recall@20 0.2299 | recall@50 0.3299 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch   7 | time: 995.59s | val loss: 0.0107 | recall@20 0.2356 | recall@50 0.3390 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch   8 | time: 1114.52s | val loss: 0.0105 | recall@20 0.2408 | recall@50 0.3449 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch   9 | time: 995.75s | val loss: 0.0103 | recall@20 0.2446 | recall@50 0.3483 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  10 | time: 1079.89s | val loss: 0.0101 | recall@20 0.2476 | recall@50 0.3524 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  11 | time: 1248.41s | val loss: 0.0100 | recall@20 0.2521 | recall@50 0.3576 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  12 | time: 1174.17s | val loss: 0.0098 | recall@20 0.2543 | recall@50 0.3591 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  13 | time: 1204.49s | val loss: 0.0097 | recall@20 0.2573 | recall@50 0.3622 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  14 | time: 996.97s | val loss: 0.0095 | recall@20 0.2601 | recall@50 0.3645 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  15 | time: 886.37s | val loss: 0.0094 | recall@20 0.2617 | recall@50 0.3664 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  16 | time: 899.47s | val loss: 0.0092 | recall@20 0.2591 | recall@50 0.3636 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  17 | time: 883.84s | val loss: 0.0091 | recall@20 0.2608 | recall@50 0.3667 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  18 | time: 875.54s | val loss: 0.0090 | recall@20 0.2610 | recall@50 0.3680 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  19 | time: 918.57s | val loss: 0.0089 | recall@20 0.2601 | recall@50 0.3668 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  20 | time: 981.96s | val loss: 0.0088 | recall@20 0.2628 | recall@50 0.3696 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  21 | time: 962.02s | val loss: 0.0087 | recall@20 0.2603 | recall@50 0.3679 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  22 | time: 927.72s | val loss: 0.0086 | recall@20 0.2605 | recall@50 0.3652 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  23 | time: 885.32s | val loss: 0.0085 | recall@20 0.2612 | recall@50 0.3672 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  24 | time: 870.00s | val loss: 0.0084 | recall@20 0.2618 | recall@50 0.3684 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  25 | time: 981.91s | val loss: 0.0083 | recall@20 0.2639 | recall@50 0.3691 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  26 | time: 867.13s | val loss: 0.0082 | recall@20 0.2611 | recall@50 0.3652 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  27 | time: 865.80s | val loss: 0.0082 | recall@20 0.2636 | recall@50 0.3680 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  28 | time: 864.95s | val loss: 0.0081 | recall@20 0.2607 | recall@50 0.3660 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  29 | time: 877.41s | val loss: 0.0080 | recall@20 0.2569 | recall@50 0.3630 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  30 | time: 858.74s | val loss: 0.0080 | recall@20 0.2599 | recall@50 0.3652 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  31 | time: 919.46s | val loss: 0.0079 | recall@20 0.2583 | recall@50 0.3644 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  32 | time: 916.76s | val loss: 0.0079 | recall@20 0.2591 | recall@50 0.3654 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  33 | time: 862.84s | val loss: 0.0078 | recall@20 0.2570 | recall@50 0.3621 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  34 | time: 857.17s | val loss: 0.0077 | recall@20 0.2570 | recall@50 0.3632 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  35 | time: 861.80s | val loss: 0.0077 | recall@20 0.2553 | recall@50 0.3602 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  36 | time: 860.53s | val loss: 0.0077 | recall@20 0.2562 | recall@50 0.3608 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  37 | time: 859.25s | val loss: 0.0076 | recall@20 0.2551 | recall@50 0.3600 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  38 | time: 859.90s | val loss: 0.0075 | recall@20 0.2526 | recall@50 0.3559 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  39 | time: 859.81s | val loss: 0.0075 | recall@20 0.2529 | recall@50 0.3566 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  40 | time: 860.27s | val loss: 0.0074 | recall@20 0.2524 | recall@50 0.3570 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  41 | time: 862.65s | val loss: 0.0074 | recall@20 0.2476 | recall@50 0.3507 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  42 | time: 857.99s | val loss: 0.0073 | recall@20 0.2486 | recall@50 0.3526 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  43 | time: 859.81s | val loss: 0.0073 | recall@20 0.2489 | recall@50 0.3530 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  44 | time: 859.09s | val loss: 0.0073 | recall@20 0.2468 | recall@50 0.3486 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  45 | time: 859.18s | val loss: 0.0072 | recall@20 0.2462 | recall@50 0.3489 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  46 | time: 861.31s | val loss: 0.0072 | recall@20 0.2458 | recall@50 0.3481 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  47 | time: 859.24s | val loss: 0.0072 | recall@20 0.2471 | recall@50 0.3483 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  48 | time: 857.06s | val loss: 0.0071 | recall@20 0.2419 | recall@50 0.3433 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  49 | time: 860.86s | val loss: 0.0071 | recall@20 0.2430 | recall@50 0.3456 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  50 | time: 858.73s | val loss: 0.0071 | recall@20 0.2418 | recall@50 0.3419 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  51 | time: 858.94s | val loss: 0.0070 | recall@20 0.2429 | recall@50 0.3452 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  52 | time: 859.82s | val loss: 0.0070 | recall@20 0.2402 | recall@50 0.3412 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  53 | time: 860.59s | val loss: 0.0070 | recall@20 0.2415 | recall@50 0.3430 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  54 | time: 858.30s | val loss: 0.0069 | recall@20 0.2393 | recall@50 0.3390 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  55 | time: 858.89s | val loss: 0.0069 | recall@20 0.2390 | recall@50 0.3394 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  56 | time: 861.20s | val loss: 0.0069 | recall@20 0.2359 | recall@50 0.3369 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  57 | time: 862.23s | val loss: 0.0069 | recall@20 0.2374 | recall@50 0.3385 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  58 | time: 859.91s | val loss: 0.0068 | recall@20 0.2346 | recall@50 0.3360 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  59 | time: 863.05s | val loss: 0.0068 | recall@20 0.2340 | recall@50 0.3336 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  60 | time: 860.49s | val loss: 0.0068 | recall@20 0.2357 | recall@50 0.3348 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  61 | time: 859.80s | val loss: 0.0067 | recall@20 0.2340 | recall@50 0.3344 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  62 | time: 863.33s | val loss: 0.0067 | recall@20 0.2360 | recall@50 0.3359 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  63 | time: 857.22s | val loss: 0.0067 | recall@20 0.2327 | recall@50 0.3318 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  64 | time: 860.61s | val loss: 0.0067 | recall@20 0.2343 | recall@50 0.3329 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  65 | time: 862.38s | val loss: 0.0066 | recall@20 0.2318 | recall@50 0.3291 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  66 | time: 859.83s | val loss: 0.0066 | recall@20 0.2295 | recall@50 0.3278 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  67 | time: 862.66s | val loss: 0.0066 | recall@20 0.2311 | recall@50 0.3302 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  68 | time: 860.91s | val loss: 0.0066 | recall@20 0.2284 | recall@50 0.3267 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  69 | time: 860.84s | val loss: 0.0065 | recall@20 0.2300 | recall@50 0.3280 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  70 | time: 862.34s | val loss: 0.0065 | recall@20 0.2296 | recall@50 0.3263 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  71 | time: 860.16s | val loss: 0.0065 | recall@20 0.2266 | recall@50 0.3251 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  72 | time: 859.32s | val loss: 0.0065 | recall@20 0.2290 | recall@50 0.3279 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  73 | time: 856.69s | val loss: 0.0065 | recall@20 0.2280 | recall@50 0.3259 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  74 | time: 862.41s | val loss: 0.0064 | recall@20 0.2253 | recall@50 0.3217 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  75 | time: 860.57s | val loss: 0.0064 | recall@20 0.2281 | recall@50 0.3261 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  76 | time: 901.77s | val loss: 0.0064 | recall@20 0.2268 | recall@50 0.3242 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  77 | time: 860.45s | val loss: 0.0064 | recall@20 0.2234 | recall@50 0.3194 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  78 | time: 859.39s | val loss: 0.0063 | recall@20 0.2257 | recall@50 0.3226 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  79 | time: 862.85s | val loss: 0.0063 | recall@20 0.2259 | recall@50 0.3237 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  80 | time: 860.20s | val loss: 0.0063 | recall@20 0.2252 | recall@50 0.3217 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  81 | time: 858.34s | val loss: 0.0063 | recall@20 0.2252 | recall@50 0.3214 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  82 | time: 860.36s | val loss: 0.0063 | recall@20 0.2220 | recall@50 0.3174 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  83 | time: 857.39s | val loss: 0.0063 | recall@20 0.2239 | recall@50 0.3190 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  84 | time: 856.55s | val loss: 0.0062 | recall@20 0.2248 | recall@50 0.3190 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  85 | time: 881.58s | val loss: 0.0062 | recall@20 0.2226 | recall@50 0.3182 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  86 | time: 873.23s | val loss: 0.0062 | recall@20 0.2209 | recall@50 0.3144 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  87 | time: 858.97s | val loss: 0.0062 | recall@20 0.2226 | recall@50 0.3186 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  88 | time: 859.51s | val loss: 0.0062 | recall@20 0.2209 | recall@50 0.3149 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  89 | time: 858.69s | val loss: 0.0062 | recall@20 0.2224 | recall@50 0.3174 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  90 | time: 860.76s | val loss: 0.0061 | recall@20 0.2213 | recall@50 0.3155 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  91 | time: 858.46s | val loss: 0.0061 | recall@20 0.2207 | recall@50 0.3134 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  92 | time: 864.33s | val loss: 0.0061 | recall@20 0.2212 | recall@50 0.3166 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  93 | time: 858.27s | val loss: 0.0061 | recall@20 0.2191 | recall@50 0.3123 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  94 | time: 857.54s | val loss: 0.0061 | recall@20 0.2171 | recall@50 0.3100 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  95 | time: 859.25s | val loss: 0.0061 | recall@20 0.2189 | recall@50 0.3119 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  96 | time: 861.47s | val loss: 0.0060 | recall@20 0.2177 | recall@50 0.3114 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  97 | time: 860.52s | val loss: 0.0060 | recall@20 0.2148 | recall@50 0.3078 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  98 | time: 859.11s | val loss: 0.0060 | recall@20 0.2183 | recall@50 0.3116 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch  99 | time: 860.73s | val loss: 0.0060 | recall@20 0.2169 | recall@50 0.3098 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 100 | time: 863.10s | val loss: 0.0060 | recall@20 0.2179 | recall@50 0.3106 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 101 | time: 860.13s | val loss: 0.0060 | recall@20 0.2165 | recall@50 0.3100 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 102 | time: 861.06s | val loss: 0.0060 | recall@20 0.2160 | recall@50 0.3078 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 103 | time: 859.73s | val loss: 0.0060 | recall@20 0.2151 | recall@50 0.3073 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 104 | time: 859.95s | val loss: 0.0059 | recall@20 0.2153 | recall@50 0.3064 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 105 | time: 863.36s | val loss: 0.0059 | recall@20 0.2161 | recall@50 0.3071 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 106 | time: 858.29s | val loss: 0.0059 | recall@20 0.2142 | recall@50 0.3040 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 107 | time: 862.66s | val loss: 0.0060 | recall@20 0.2160 | recall@50 0.3084 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 108 | time: 859.12s | val loss: 0.0059 | recall@20 0.2145 | recall@50 0.3059 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 109 | time: 858.43s | val loss: 0.0059 | recall@20 0.2132 | recall@50 0.3025 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 110 | time: 858.13s | val loss: 0.0059 | recall@20 0.2133 | recall@50 0.3031 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 111 | time: 859.07s | val loss: 0.0059 | recall@20 0.2146 | recall@50 0.3067 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 112 | time: 857.70s | val loss: 0.0058 | recall@20 0.2120 | recall@50 0.3019 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 113 | time: 860.56s | val loss: 0.0058 | recall@20 0.2121 | recall@50 0.3036 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 114 | time: 860.49s | val loss: 0.0058 | recall@20 0.2131 | recall@50 0.3042 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 115 | time: 861.82s | val loss: 0.0058 | recall@20 0.2117 | recall@50 0.3013 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 116 | time: 860.83s | val loss: 0.0058 | recall@20 0.2134 | recall@50 0.3040 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 117 | time: 859.24s | val loss: 0.0058 | recall@20 0.2115 | recall@50 0.3026 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 118 | time: 860.61s | val loss: 0.0058 | recall@20 0.2121 | recall@50 0.3020 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 119 | time: 855.91s | val loss: 0.0058 | recall@20 0.2104 | recall@50 0.3010 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 120 | time: 858.87s | val loss: 0.0058 | recall@20 0.2106 | recall@50 0.2997 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 121 | time: 860.55s | val loss: 0.0057 | recall@20 0.2100 | recall@50 0.2983 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 122 | time: 862.06s | val loss: 0.0057 | recall@20 0.2091 | recall@50 0.2978 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 123 | time: 860.73s | val loss: 0.0057 | recall@20 0.2108 | recall@50 0.2993 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 124 | time: 858.48s | val loss: 0.0057 | recall@20 0.2132 | recall@50 0.3035 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 125 | time: 862.44s | val loss: 0.0057 | recall@20 0.2089 | recall@50 0.2963 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 126 | time: 859.51s | val loss: 0.0057 | recall@20 0.2103 | recall@50 0.3008 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 127 | time: 859.67s | val loss: 0.0057 | recall@20 0.2097 | recall@50 0.2980 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 128 | time: 858.25s | val loss: 0.0057 | recall@20 0.2084 | recall@50 0.2984 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 129 | time: 860.97s | val loss: 0.0057 | recall@20 0.2092 | recall@50 0.2984 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 130 | time: 860.83s | val loss: 0.0057 | recall@20 0.2097 | recall@50 0.2985 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 131 | time: 859.92s | val loss: 0.0056 | recall@20 0.2063 | recall@50 0.2940 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 132 | time: 859.62s | val loss: 0.0056 | recall@20 0.2040 | recall@50 0.2923 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 133 | time: 858.00s | val loss: 0.0056 | recall@20 0.2085 | recall@50 0.2982 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 134 | time: 856.62s | val loss: 0.0056 | recall@20 0.2058 | recall@50 0.2936 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 135 | time: 859.84s | val loss: 0.0056 | recall@20 0.2083 | recall@50 0.2974 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 136 | time: 859.60s | val loss: 0.0056 | recall@20 0.2073 | recall@50 0.2964 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 137 | time: 859.72s | val loss: 0.0056 | recall@20 0.2054 | recall@50 0.2941 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 138 | time: 858.68s | val loss: 0.0056 | recall@20 0.2095 | recall@50 0.2988 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 139 | time: 861.03s | val loss: 0.0056 | recall@20 0.2067 | recall@50 0.2968 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 140 | time: 858.92s | val loss: 0.0056 | recall@20 0.2032 | recall@50 0.2918 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 141 | time: 864.46s | val loss: 0.0055 | recall@20 0.2023 | recall@50 0.2904 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 142 | time: 859.68s | val loss: 0.0056 | recall@20 0.2070 | recall@50 0.2969 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 143 | time: 860.18s | val loss: 0.0056 | recall@20 0.2065 | recall@50 0.2954 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 144 | time: 855.98s | val loss: 0.0055 | recall@20 0.2022 | recall@50 0.2904 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 145 | time: 859.23s | val loss: 0.0056 | recall@20 0.2062 | recall@50 0.2951 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 146 | time: 861.56s | val loss: 0.0055 | recall@20 0.2039 | recall@50 0.2909 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 147 | time: 860.18s | val loss: 0.0055 | recall@20 0.2020 | recall@50 0.2897 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 148 | time: 858.92s | val loss: 0.0055 | recall@20 0.2035 | recall@50 0.2917 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 149 | time: 860.72s | val loss: 0.0055 | recall@20 0.2033 | recall@50 0.2917 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 150 | time: 858.84s | val loss: 0.0055 | recall@20 0.2039 | recall@50 0.2937 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 151 | time: 859.47s | val loss: 0.0055 | recall@20 0.2013 | recall@50 0.2901 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 152 | time: 864.54s | val loss: 0.0055 | recall@20 0.2066 | recall@50 0.2973 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 153 | time: 860.87s | val loss: 0.0055 | recall@20 0.2046 | recall@50 0.2925 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 154 | time: 859.57s | val loss: 0.0055 | recall@20 0.2003 | recall@50 0.2892 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 155 | time: 862.77s | val loss: 0.0055 | recall@20 0.2068 | recall@50 0.2958 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 156 | time: 858.55s | val loss: 0.0055 | recall@20 0.2047 | recall@50 0.2943 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 157 | time: 859.92s | val loss: 0.0055 | recall@20 0.2041 | recall@50 0.2930 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 158 | time: 862.85s | val loss: 0.0054 | recall@20 0.2024 | recall@50 0.2899 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 159 | time: 859.50s | val loss: 0.0054 | recall@20 0.2037 | recall@50 0.2921 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 160 | time: 858.56s | val loss: 0.0054 | recall@20 0.2023 | recall@50 0.2911 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 161 | time: 864.35s | val loss: 0.0054 | recall@20 0.2010 | recall@50 0.2896 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 162 | time: 861.20s | val loss: 0.0054 | recall@20 0.2029 | recall@50 0.2912 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 163 | time: 862.92s | val loss: 0.0054 | recall@20 0.2003 | recall@50 0.2888 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 164 | time: 859.38s | val loss: 0.0054 | recall@20 0.2015 | recall@50 0.2895 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 165 | time: 858.45s | val loss: 0.0054 | recall@20 0.2025 | recall@50 0.2915 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 166 | time: 855.99s | val loss: 0.0054 | recall@20 0.2013 | recall@50 0.2889 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 167 | time: 864.92s | val loss: 0.0054 | recall@20 0.2059 | recall@50 0.2952 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 168 | time: 860.93s | val loss: 0.0054 | recall@20 0.2016 | recall@50 0.2891 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 169 | time: 856.40s | val loss: 0.0054 | recall@20 0.2030 | recall@50 0.2915 |
# ...
# | end of epoch 239 | time: 860.39s | val loss: 0.0051 | recall@20 0.1991 | recall@50 0.2877 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 240 | time: 859.10s | val loss: 0.0051 | recall@20 0.1971 | recall@50 0.2853 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 241 | time: 859.21s | val loss: 0.0051 | recall@20 0.1998 | recall@50 0.2891 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 242 | time: 859.16s | val loss: 0.0051 | recall@20 0.1973 | recall@50 0.2862 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 243 | time: 858.63s | val loss: 0.0051 | recall@20 0.1942 | recall@50 0.2800 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 244 | time: 861.29s | val loss: 0.0051 | recall@20 0.1956 | recall@50 0.2826 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 245 | time: 858.71s | val loss: 0.0051 | recall@20 0.1979 | recall@50 0.2862 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 246 | time: 859.66s | val loss: 0.0051 | recall@20 0.1980 | recall@50 0.2858 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 247 | time: 857.01s | val loss: 0.0051 | recall@20 0.1985 | recall@50 0.2873 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 248 | time: 859.12s | val loss: 0.0051 | recall@20 0.1963 | recall@50 0.2833 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 249 | time: 857.43s | val loss: 0.0051 | recall@20 0.1979 | recall@50 0.2870 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 250 | time: 857.45s | val loss: 0.0051 | recall@20 0.1989 | recall@50 0.2867 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 251 | time: 858.54s | val loss: 0.0050 | recall@20 0.1944 | recall@50 0.2824 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 252 | time: 858.98s | val loss: 0.0051 | recall@20 0.1991 | recall@50 0.2884 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 253 | time: 858.56s | val loss: 0.0050 | recall@20 0.1956 | recall@50 0.2840 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 254 | time: 859.31s | val loss: 0.0050 | recall@20 0.1951 | recall@50 0.2821 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 255 | time: 857.91s | val loss: 0.0050 | recall@20 0.1969 | recall@50 0.2856 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 256 | time: 858.40s | val loss: 0.0050 | recall@20 0.1956 | recall@50 0.2831 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 257 | time: 859.39s | val loss: 0.0050 | recall@20 0.1940 | recall@50 0.2809 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 258 | time: 857.56s | val loss: 0.0050 | recall@20 0.1942 | recall@50 0.2812 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 259 | time: 858.57s | val loss: 0.0050 | recall@20 0.1952 | recall@50 0.2830 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 260 | time: 859.66s | val loss: 0.0050 | recall@20 0.1958 | recall@50 0.2827 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 261 | time: 857.52s | val loss: 0.0050 | recall@20 0.1949 | recall@50 0.2843 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 262 | time: 858.83s | val loss: 0.0050 | recall@20 0.1952 | recall@50 0.2833 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 263 | time: 857.19s | val loss: 0.0050 | recall@20 0.1951 | recall@50 0.2828 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 264 | time: 857.11s | val loss: 0.0050 | recall@20 0.1993 | recall@50 0.2886 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 265 | time: 860.73s | val loss: 0.0050 | recall@20 0.1964 | recall@50 0.2850 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 266 | time: 857.43s | val loss: 0.0050 | recall@20 0.1952 | recall@50 0.2822 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 267 | time: 858.94s | val loss: 0.0050 | recall@20 0.1951 | recall@50 0.2841 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 268 | time: 858.96s | val loss: 0.0050 | recall@20 0.1952 | recall@50 0.2838 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 269 | time: 901.64s | val loss: 0.0050 | recall@20 0.1988 | recall@50 0.2867 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 270 | time: 858.96s | val loss: 0.0050 | recall@20 0.1966 | recall@50 0.2850 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 271 | time: 858.51s | val loss: 0.0050 | recall@20 0.1979 | recall@50 0.2879 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 272 | time: 857.66s | val loss: 0.0050 | recall@20 0.1953 | recall@50 0.2839 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 273 | time: 858.85s | val loss: 0.0050 | recall@20 0.1966 | recall@50 0.2855 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 274 | time: 858.68s | val loss: 0.0050 | recall@20 0.1965 | recall@50 0.2851 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 275 | time: 858.56s | val loss: 0.0050 | recall@20 0.1944 | recall@50 0.2844 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 276 | time: 860.60s | val loss: 0.0050 | recall@20 0.1962 | recall@50 0.2853 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 277 | time: 860.54s | val loss: 0.0050 | recall@20 0.1958 | recall@50 0.2847 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 278 | time: 856.93s | val loss: 0.0050 | recall@20 0.1972 | recall@50 0.2866 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 279 | time: 858.35s | val loss: 0.0050 | recall@20 0.1947 | recall@50 0.2827 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 280 | time: 861.34s | val loss: 0.0050 | recall@20 0.1959 | recall@50 0.2860 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 281 | time: 858.07s | val loss: 0.0050 | recall@20 0.1968 | recall@50 0.2856 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 282 | time: 857.85s | val loss: 0.0050 | recall@20 0.1965 | recall@50 0.2854 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 283 | time: 857.54s | val loss: 0.0050 | recall@20 0.1955 | recall@50 0.2846 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 284 | time: 903.53s | val loss: 0.0050 | recall@20 0.1975 | recall@50 0.2874 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 285 | time: 857.08s | val loss: 0.0050 | recall@20 0.1963 | recall@50 0.2867 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 286 | time: 857.84s | val loss: 0.0050 | recall@20 0.1943 | recall@50 0.2818 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 287 | time: 860.76s | val loss: 0.0050 | recall@20 0.2001 | recall@50 0.2894 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 288 | time: 858.37s | val loss: 0.0050 | recall@20 0.1954 | recall@50 0.2830 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 289 | time: 858.08s | val loss: 0.0050 | recall@20 0.1972 | recall@50 0.2857 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 290 | time: 857.64s | val loss: 0.0050 | recall@20 0.1952 | recall@50 0.2818 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 291 | time: 858.11s | val loss: 0.0050 | recall@20 0.1979 | recall@50 0.2881 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 292 | time: 859.28s | val loss: 0.0049 | recall@20 0.1978 | recall@50 0.2859 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 293 | time: 858.29s | val loss: 0.0050 | recall@20 0.1968 | recall@50 0.2842 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# | end of epoch 294 | time: 857.46s | val loss: 0.0050 | recall@20 0.1934 | recall@50 0.2814 |
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Exiting from training early

# %%
"Batch 1"

# Load the best saved model.
with open(log_dir + 'user_embs_sum.pt', 'rb') as f:
    model = torch.load(f)

recall_20, recall_50, _ = att_test(te_tr_data, te_te_data)

print(recall_20, recall_50)
# Out:
# 0.2660992136355217 0.3736796119788061
